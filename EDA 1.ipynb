# %%
import numpy as np
import pandas as pd
data=pd.read_csv('Downloads\\data_clean.csv')
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data=data.iloc[:,1:]
data
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4      NaN      NaN  14.3     56     5    5  2010    56       S
# ..     ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     67     5    1  2010    67       C
# 154   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155    NaN    145.0  13.2     77     9   27  2010    77       S
# 156   14.0    191.0  14.3     75     9   28  2010    75       S
# 157   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data.describe()
# Out:
#             Ozone     Solar.R        Wind         Day    Year        Temp
# count  120.000000  151.000000  158.000000  158.000000   158.0  158.000000
# mean    41.583333  185.403974    9.957595   16.006329  2010.0   77.727848
# std     32.620709   88.723103    3.511261    8.997166     0.0    9.377877
# min      1.000000    7.000000    1.700000    1.000000  2010.0   56.000000
# 25%     18.000000  119.000000    7.400000    8.000000  2010.0   72.000000
# 50%     30.500000  197.000000    9.700000   16.000000  2010.0   78.500000
# 75%     61.500000  257.000000   11.875000   24.000000  2010.0   84.000000
# max    168.000000  334.000000   20.700000   31.000000  2010.0   97.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Temp C   158 non-null    object
#  4   Month    158 non-null    object
#  5   Day      158 non-null    int64
#  6   Year     158 non-null    int64
#  7   Temp     158 non-null    int64
#  8   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 11.2+ KB

# %%
data.shape
# Out:
# (158, 9)

# %%
data['Temp C'].unique()
# Out:
# array(['67', '72', '74', '62', '56', '66', '65', '59', '61', '69', 'C',
#        '68', '58', '64', '57', '73', '81', '79', '76', '78', '84', '85',
#        '82', '87', '90', '93', '92', '80', '77', '75', '83', '88', '89',
#        '91', '86', '97', '94', '96', '71', '63', '70'], dtype=object)

# %%
data['Month'].unique()
# Out:
# array(['5', 'May', '6', '7', '8', '9'], dtype=object)

# %%
data[data['Month']=='May']
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 23   32.0     92.0  12.0     61   May   24  2010    61       C

# %%
data['Month']=data['Month'].replace('May',5)
data['Month'].unique()
# Out:
# array(['5', 5, '6', '7', '8', '9'], dtype=object)

# %%
data[data['Temp C']=='C']
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 10    7.0      NaN   6.9      C     5   11  2010    74       C

# %%
data['Weather'].unique()
# Out:
# array(['S', 'C', 'PS', nan], dtype=object)

# %%
data['Month']=pd.to_numeric(data['Month'],errors='coerce')

# %%
data['Temp C']=pd.to_numeric(data['Temp C'],errors='coerce')

# %%
data['Weather'].astype('category')
# Out:
# 0       S
# 1       C
# 2      PS
# 3       S
# 4       S
#        ..
# 153     C
# 154    PS
# 155     S
# 156     S
# 157     C
# Name: Weather, Length: 158, dtype: category
# Categories (3, object): ['C', 'PS', 'S']

# %%
data['Month'].unique()
# Out:
# array([5, 6, 7, 8, 9], dtype=int64)

# %%
data.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C     float64
# Month        int64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
data[data.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    75.0      9   28  2010    75       S

# %%
data[data['Solar.R']==191]
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 46    21.0    191.0  14.9    77.0      6   16  2010    77      PS
# 150   14.0    191.0  14.3    75.0      9   28  2010    75       S
# 156   14.0    191.0  14.3    75.0      9   28  2010    75       S

# %%
data[data.duplicated()].shape
# Out:
# (1, 9)

# %%
data=data.drop_duplicates()

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %%
data[['Temp C','Temp']].head(10)
# Out:
#    Temp C  Temp
# 0    67.0    67
# 1    72.0    72
# 2    74.0    74
# 3    62.0    62
# 4    56.0    56
# 5    66.0    66
# 6    65.0    65
# 7    59.0    59
# 8    61.0    61
# 9    69.0    69

# %%
data[data['Temp C']!=data['Temp']]
# Out:
#     Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 10    7.0      NaN   6.9     NaN      5   11  2010    74       C

# %%
data=data.drop('Temp C',axis=1)
data
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      5    1  2010    67       S
# 1     36.0    118.0   8.0      5    2  2010    72       C
# 2     12.0    149.0  12.6      5    3  2010    74      PS
# 3     18.0    313.0  11.5      5    4  2010    62       S
# 4      NaN      NaN  14.3      5    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5      9   30  2010    68       S
# 153   41.0    190.0   7.4      5    1  2010    67       C
# 154   30.0    193.0   6.9      9   26  2010    70      PS
# 155    NaN    145.0  13.2      9   27  2010    77       S
# 157   18.0    131.0   8.0      9   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data['Year'].unique()
# Out:
# array([2010], dtype=int64)

# %%
data=data.drop('Year',axis=1)
data
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Temp Weather
# 0     41.0    190.0   7.4      5    1    67       S
# 1     36.0    118.0   8.0      5    2    72       C
# 2     12.0    149.0  12.6      5    3    74      PS
# 3     18.0    313.0  11.5      5    4    62       S
# 4      NaN      NaN  14.3      5    5    56       S
# ..     ...      ...   ...    ...  ...   ...     ...
# 152   20.0    223.0  11.5      9   30    68       S
# 153   41.0    190.0   7.4      5    1    67       C
# 154   30.0    193.0   6.9      9   26    70      PS
# 155    NaN    145.0  13.2      9   27    77       S
# 157   18.0    131.0   8.0      9   29    76       C
#
# [157 rows x 7 columns]

# %%
data=data.rename({'Solar.R':'Solar','Temp':'Temp F'},axis=1)
data
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp F Weather
# 0     41.0  190.0   7.4      5    1      67       S
# 1     36.0  118.0   8.0      5    2      72       C
# 2     12.0  149.0  12.6      5    3      74      PS
# 3     18.0  313.0  11.5      5    4      62       S
# 4      NaN    NaN  14.3      5    5      56       S
# ..     ...    ...   ...    ...  ...     ...     ...
# 152   20.0  223.0  11.5      9   30      68       S
# 153   41.0  190.0   7.4      5    1      67       C
# 154   30.0  193.0   6.9      9   26      70      PS
# 155    NaN  145.0  13.2      9   27      77       S
# 157   18.0  131.0   8.0      9   29      76       C
#
# [157 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data['Ozone'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.hist(data['Ozone'])
# Out:
# (array([28., 36., 21.,  9., 11.,  7.,  3.,  2.,  1.,  1.]),
#  array([  1. ,  17.7,  34.4,  51.1,  67.8,  84.5, 101.2, 117.9, 134.6,
#         151.3, 168. ]),
#  <BarContainer object of 10 artists>)

# %%
data.boxplot(column=['Ozone'],grid=True)
# Out:
# <AxesSubplot:>

# %%
data['Ozone'].describe()
# Out:
# count    119.000000
# mean      41.815126
# std       32.659249
# min        1.000000
# 25%       18.000000
# 50%       31.000000
# 75%       62.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
print('Interquartile Range',62-18)
# Out:
# Interquartile Range 44

# %%
print('Upper Limit',62+1.5*(62-18))
# Out:
# Upper Limit 128.0

# %%
print('Lower Limit',18-1.5*(62-18))
# Out:
# Lower Limit -48.0

# %%
data[data['Ozone']>128]
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp F Weather
# 61   135.0  269.0   4.1      7    1      84       S
# 116  168.0  238.0   3.4      8   25      81      PS

# %%
Ozone_Outliers=data[data['Ozone']>128]
Ozone_Outliers
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp F Weather
# 61   135.0  269.0   4.1      7    1      84       S
# 116  168.0  238.0   3.4      8   25      81      PS

# %%
data['Weather'].value_counts()
# Out:
# S     58
# C     49
# PS    47
# Name: Weather, dtype: int64

# %%
data['Weather'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(data['Wind'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x242cf3a14c0>,
#   <matplotlib.lines.Line2D at 0x242cf3a1850>],
#  'caps': [<matplotlib.lines.Line2D at 0x242cf3a1be0>,
#   <matplotlib.lines.Line2D at 0x242cf3a1f70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x242cf3a1130>],
#  'medians': [<matplotlib.lines.Line2D at 0x242cf3af340>],
#  'fliers': [<matplotlib.lines.Line2D at 0x242cf3af6d0>],
#  'means': []}

# %%
plt.boxplot(data['Solar'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x242cf40e970>,
#   <matplotlib.lines.Line2D at 0x242cf40ed00>],
#  'caps': [<matplotlib.lines.Line2D at 0x242cf41b0d0>,
#   <matplotlib.lines.Line2D at 0x242cf41b400>],
#  'boxes': [<matplotlib.lines.Line2D at 0x242cf40e5e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x242cf41b790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x242cf41bb20>],
#  'means': []}

# %%
plt.boxplot(data['Temp F'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x242cf46cfd0>,
#   <matplotlib.lines.Line2D at 0x242cf47a3a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x242cf47a730>,
#   <matplotlib.lines.Line2D at 0x242cf47aac0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x242cf46cc40>],
#  'medians': [<matplotlib.lines.Line2D at 0x242cf47ae50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x242cf486220>],
#  'means': []}

# %%
import seaborn as sns
cols=data.columns
cols
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Temp F', 'Weather'], dtype='object')

# %%
colours=['Blue','Yellow']
sns.heatmap(data[cols].isnull(),cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:>

# %%
data.shape
# Out:
# (157, 7)

# %%
data.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       0
# Day         0
# Temp F      0
# Weather     3
# dtype: int64

# %%
print('The % of missing values in Ozone is',(38/157)*100)
# Out:
# The % of missing values in Ozone is 24.203821656050955

# %%
print('The % of missing values in Solar is',(7/157)*100)
# Out:
# The % of missing values in Solar is 4.45859872611465

# %%
print('The % of missing values in Weather is',(3/157)*100)
# Out:
# The % of missing values in Weather is 1.910828025477707

# %%
data['Solar'].skew()
# Out:
# -0.4141167126969295

# %%
Solar_mean=data['Solar'].mean()
print(Solar_mean)
# Out:
# 185.36666666666667

# %%
Solar_median=data['Solar'].median()
print(Solar_median)
# Out:
# 199.0

# %%
data['Solar']=data['Solar'].fillna(Solar_median)
data['Solar'].isnull().sum()
# Out:
# 0

# %%
data[data.isnull().any(axis=1)]
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp F Weather
# 4      NaN  199.0  14.3      5    5      56       S
# 9      NaN  194.0   8.6      5   10      69       S
# 24     NaN   66.0  16.6      5   25      57      PS
# 25     NaN  266.0  14.9      5   26      58       C
# 26     NaN  199.0   8.0      5   27      57      PS
# 31     NaN  286.0   8.6      6    1      78       S
# 32     NaN  287.0   9.7      6    2      74       C
# 33     NaN  242.0  16.1      6    3      67      PS
# 34     NaN  186.0   9.2      6    4      84       C
# 35     NaN  220.0   8.6      6    5      85      PS
# 36     NaN  264.0  14.3      6    6      79       C
# 38     NaN  273.0   6.9      6    8      87       S
# 41     NaN  259.0  10.9      6   11      93       C
# 42     NaN  250.0   9.2      6   12      92      PS
# 44     NaN  332.0  13.8      6   14      80       S
# 45     NaN  322.0  11.5      6   15      79       C
# 51     NaN  150.0   6.3      6   21      77       S
# 52     NaN   59.0   1.7      6   22      76       C
# 53     NaN   91.0   4.6      6   23      76      PS
# 54     NaN  250.0   6.3      6   24      76       S
# 55     NaN  135.0   8.0      6   25      75       C
# 56     NaN  127.0   8.0      6   26      78      PS
# 57     NaN   47.0  10.3      6   27      73       C
# 58     NaN   98.0  11.5      6   28      80      PS
# 59     NaN   31.0  14.9      6   29      77       S
# 60     NaN  138.0   8.0      6   30      83       S
# 64     NaN  101.0  10.9      7    4      84       S
# 71     NaN  139.0   8.6      7   11      82       S
# 74     NaN  291.0  14.9      7   14      91       C
# 82     NaN  258.0   9.7      7   22      81       S
# 83     NaN  295.0  11.5      7   23      82       C
# 87    52.0   82.0  12.0      7   27      86     NaN
# 93     9.0   24.0  13.8      8    2      81     NaN
# 95    78.0  199.0   6.9      8    4      86     NaN
# 101    NaN  222.0   8.6      8   10      92      PS
# 102    NaN  137.0  11.5      8   11      86       S
# 106    NaN   64.0  11.5      8   15      79       C
# 114    NaN  255.0  12.6      8   23      75      PS
# 118    NaN  153.0   5.7      8   27      88       S
# 149    NaN  145.0  13.2      9   27      77      PS
# 155    NaN  145.0  13.2      9   27      77       S

# %%
data.isnull().sum()
# Out:
# Ozone      38
# Solar       0
# Wind        0
# Month       0
# Day         0
# Temp F      0
# Weather     3
# dtype: int64

# %%
data['Solar_Bin']=pd.cut(x=data['Solar'],bins=[0,50,100,150,200,250,300,350],right=True,labels=['a','b','c','d','e','f','g'])
data
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp F Weather Solar_Bin
# 0     41.0  190.0   7.4      5    1      67       S         d
# 1     36.0  118.0   8.0      5    2      72       C         c
# 2     12.0  149.0  12.6      5    3      74      PS         c
# 3     18.0  313.0  11.5      5    4      62       S         g
# 4      NaN  199.0  14.3      5    5      56       S         d
# ..     ...    ...   ...    ...  ...     ...     ...       ...
# 152   20.0  223.0  11.5      9   30      68       S         e
# 153   41.0  190.0   7.4      5    1      67       C         d
# 154   30.0  193.0   6.9      9   26      70      PS         d
# 155    NaN  145.0  13.2      9   27      77       S         c
# 157   18.0  131.0   8.0      9   29      76       C         c
#
# [157 rows x 8 columns]

# %%
Ozone_Bins=pd.DataFrame(data['Ozone'].groupby(data['Solar_Bin']).mean())
Ozone_Bins
# Out:
#                Ozone
# Solar_Bin
# a          11.600000
# b          30.166667
# c          21.181818
# d          53.130435
# e          59.840000
# f          50.115385
# g          26.571429

# %%
data['Ozone_Full']=data['Ozone'].fillna(data.groupby('Solar_Bin')['Ozone'].transform('mean'))

# %%
data[data[['Ozone_Full','Ozone','Solar_Bin']].isnull().any(axis=1)]
# Out:
#      Ozone  Solar  Wind  Month  Day  Temp F Weather Solar_Bin  Ozone_Full
# 4      NaN  199.0  14.3      5    5      56       S         d   53.130435
# 9      NaN  194.0   8.6      5   10      69       S         d   53.130435
# 24     NaN   66.0  16.6      5   25      57      PS         b   30.166667
# 25     NaN  266.0  14.9      5   26      58       C         f   50.115385
# 26     NaN  199.0   8.0      5   27      57      PS         d   53.130435
# 31     NaN  286.0   8.6      6    1      78       S         f   50.115385
# 32     NaN  287.0   9.7      6    2      74       C         f   50.115385
# 33     NaN  242.0  16.1      6    3      67      PS         e   59.840000
# 34     NaN  186.0   9.2      6    4      84       C         d   53.130435
# 35     NaN  220.0   8.6      6    5      85      PS         e   59.840000
# 36     NaN  264.0  14.3      6    6      79       C         f   50.115385
# 38     NaN  273.0   6.9      6    8      87       S         f   50.115385
# 41     NaN  259.0  10.9      6   11      93       C         f   50.115385
# 42     NaN  250.0   9.2      6   12      92      PS         e   59.840000
# 44     NaN  332.0  13.8      6   14      80       S         g   26.571429
# 45     NaN  322.0  11.5      6   15      79       C         g   26.571429
# 51     NaN  150.0   6.3      6   21      77       S         c   21.181818
# 52     NaN   59.0   1.7      6   22      76       C         b   30.166667
# 53     NaN   91.0   4.6      6   23      76      PS         b   30.166667
# 54     NaN  250.0   6.3      6   24      76       S         e   59.840000
# 55     NaN  135.0   8.0      6   25      75       C         c   21.181818
# 56     NaN  127.0   8.0      6   26      78      PS         c   21.181818
# 57     NaN   47.0  10.3      6   27      73       C         a   11.600000
# 58     NaN   98.0  11.5      6   28      80      PS         b   30.166667
# 59     NaN   31.0  14.9      6   29      77       S         a   11.600000
# 60     NaN  138.0   8.0      6   30      83       S         c   21.181818
# 64     NaN  101.0  10.9      7    4      84       S         c   21.181818
# 71     NaN  139.0   8.6      7   11      82       S         c   21.181818
# 74     NaN  291.0  14.9      7   14      91       C         f   50.115385
# 82     NaN  258.0   9.7      7   22      81       S         f   50.115385
# 83     NaN  295.0  11.5      7   23      82       C         f   50.115385
# 101    NaN  222.0   8.6      8   10      92      PS         e   59.840000
# 102    NaN  137.0  11.5      8   11      86       S         c   21.181818
# 106    NaN   64.0  11.5      8   15      79       C         b   30.166667
# 114    NaN  255.0  12.6      8   23      75      PS         f   50.115385
# 118    NaN  153.0   5.7      8   27      88       S         d   53.130435
# 149    NaN  145.0  13.2      9   27      77      PS         c   21.181818
# 155    NaN  145.0  13.2      9   27      77       S         c   21.181818

# %%
data.isnull().sum()
# Out:
# Ozone         38
# Solar          0
# Wind           0
# Month          0
# Day            0
# Temp F         0
# Weather        3
# Solar_Bin      0
# Ozone_Full     0
# dtype: int64

# %%
data.drop('Ozone',axis=1,inplace=True)

# %%
data.drop('Solar_Bin',axis=1,inplace=True)

# %%
data.rename({'Ozone_Full':'Ozone'},axis=1,inplace=True)
data
# Out:
#      Solar  Wind  Month  Day  Temp F Weather      Ozone
# 0    190.0   7.4      5    1      67       S  41.000000
# 1    118.0   8.0      5    2      72       C  36.000000
# 2    149.0  12.6      5    3      74      PS  12.000000
# 3    313.0  11.5      5    4      62       S  18.000000
# 4    199.0  14.3      5    5      56       S  53.130435
# ..     ...   ...    ...  ...     ...     ...        ...
# 152  223.0  11.5      9   30      68       S  20.000000
# 153  190.0   7.4      5    1      67       C  41.000000
# 154  193.0   6.9      9   26      70      PS  30.000000
# 155  145.0  13.2      9   27      77       S  21.181818
# 157  131.0   8.0      9   29      76       C  18.000000
#
# [157 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# Solar      0
# Wind       0
# Month      0
# Day        0
# Temp F     0
# Weather    3
# Ozone      0
# dtype: int64

# %%
data.groupby('Weather')['Temp F'].mean()
# Out:
# Weather
# C     77.734694
# PS    76.872340
# S     78.120690
# Name: Temp F, dtype: float64

# %%
data['Weather'].mode()
# Out:
# 0    S
# dtype: object

# %%
data[data['Weather'].isnull()]
# Out:
#     Solar  Wind  Month  Day  Temp F Weather  Ozone
# 87   82.0  12.0      7   27      86     NaN   52.0
# 93   24.0  13.8      8    2      81     NaN    9.0
# 95  199.0   6.9      8    4      86     NaN   78.0

# %%
data['Weather']=data['Weather'].fillna('S')

# %%
data.isnull().sum()
# Out:
# Solar      0
# Wind       0
# Month      0
# Day        0
# Temp F     0
# Weather    0
# Ozone      0
# dtype: int64

# %%
import seaborn as sns
sns.pairplot(data)

# %%
data.corr()
# Out:
#            Solar      Wind     Month       Day    Temp F     Ozone
# Solar   1.000000 -0.057709 -0.083788 -0.156243  0.256994  0.374151
# Wind   -0.057709  1.000000 -0.170328  0.029900 -0.441228 -0.507476
# Month  -0.083788 -0.170328  1.000000  0.041438  0.408060  0.122163
# Day    -0.156243  0.029900  0.041438  1.000000 -0.122787 -0.084178
# Temp F  0.256994 -0.441228  0.408060 -0.122787  1.000000  0.587968
# Ozone   0.374151 -0.507476  0.122163 -0.084178  0.587968  1.000000

# %%
data=pd.get_dummies(data,columns=['Weather'])
data
# Out:
#      Solar  Wind  Month  Day  Temp F      Ozone  Weather_C  Weather_PS  \
# 0    190.0   7.4      5    1      67  41.000000          0           0
# 1    118.0   8.0      5    2      72  36.000000          1           0
# 2    149.0  12.6      5    3      74  12.000000          0           1
# 3    313.0  11.5      5    4      62  18.000000          0           0
# 4    199.0  14.3      5    5      56  53.130435          0           0
# ..     ...   ...    ...  ...     ...        ...        ...         ...
# 152  223.0  11.5      9   30      68  20.000000          0           0
# 153  190.0   7.4      5    1      67  41.000000          1           0
# 154  193.0   6.9      9   26      70  30.000000          0           1
# 155  145.0  13.2      9   27      77  21.181818          0           0
# 157  131.0   8.0      9   29      76  18.000000          1           0
#
#      Weather_S
# 0            1
# 1            0
# 2            0
# 3            1
# 4            1
# ..         ...
# 152          1
# 153          0
# 154          0
# 155          1
# 157          0
#
# [157 rows x 9 columns]

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
array1=data.values
array1
# Out:
# array([[190. ,   7.4,   5. , ...,   0. ,   0. ,   1. ],
#        [118. ,   8. ,   5. , ...,   1. ,   0. ,   0. ],
#        [149. ,  12.6,   5. , ...,   0. ,   1. ,   0. ],
#        ...,
#        [193. ,   6.9,   9. , ...,   0. ,   1. ,   0. ],
#        [145. ,  13.2,   9. , ...,   0. ,   0. ,   1. ],
#        [131. ,   8. ,   9. , ...,   1. ,   0. ,   0. ]])

# %%
scaler=MinMaxScaler(feature_range=(0,1))
rescaledx=scaler.fit_transform(array1)
rescaledx
# Out:
# array([[0.55963303, 0.3       , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.33944954, 0.33157895, 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.43425076, 0.57368421, 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.56880734, 0.27368421, 1.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.42201835, 0.60526316, 1.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.37920489, 0.33157895, 1.        , ..., 1.        , 0.        ,
#         0.        ]])

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler=StandardScaler()
rescaledx=scaler.fit_transform(array1)
rescaledx
# Out:
# array([[0.55963303, 0.3       , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.33944954, 0.33157895, 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.43425076, 0.57368421, 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.56880734, 0.27368421, 1.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.42201835, 0.60526316, 1.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.37920489, 0.33157895, 1.        , ..., 1.        , 0.        ,
#         0.        ]])
